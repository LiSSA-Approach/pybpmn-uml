# %%
import os, sys, math, logging, random
from pathlib import Path

import numpy as np

# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

logging.basicConfig(level=logging.INFO, stream=sys.stdout)

import yamlu

from pybpmn.uml_dataset import UmlDataset
from pybpmn import constants
from pybpmn.vis import Visualizer

# %%
project_root = Path().absolute().parent

# assumes that UML data has been stored instead of the provided example_dataset
# NOTE: change this if required
uml_dataset_root = project_root / "example-dataset" / "uml-dataset"

# where to store the COCO formatted dataset
coco_dataset_root = project_root / "example-dataset" / "coco"

ds = UmlDataset(uml_dataset_root, coco_dataset_root)
# Out:
# INFO:pybpmn.uml_dataset:Parsed UML dataset with 3 images: {'test': 1, 'train': 1, 'val': 1}

# %% [markdown]
# # Parse BPMN XML into AnnotatedImage

# %%
ai = ds.get_split_ann_img("train", 0)
print(ai)
ai.plot(figsize=(12,12))
# Out:
# AnnotatedImage(filename='umlDiagram_train.jpeg', size=(1193, 1405), 20 annotations (Counter({'Label': 10, 'Class': 4, 'Interface': 1, 'Dependency': 1, 'Realization': 1, 'Association': 1, 'Extension': 1, 'Aggregation': 1})))
